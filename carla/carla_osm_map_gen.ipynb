# %%
import carla

# %%
# Read the .osm data
f = open("/home/toffanetto/autoware/Maps/vilma_autoware_maps/carla/unicamp_osm.osm", 'r')
osm_data = f.read()
f.close()

# Define the desired settings. In this case, default values.
settings = carla.Osm2OdrSettings()
# Set OSM road types to export to OpenDRIVE
settings.set_osm_way_types(["motorway", "motorway_link", "trunk", "trunk_link", "primary", "primary_link", "secondary", "secondary_link", "tertiary", "tertiary_link", "unclassified", "residential"])
# Convert to .xodr
xodr_data = carla.Osm2Odr.convert(osm_data, settings)

# save opendrive file
f = open("/home/toffanetto/autoware/Maps/vilma_autoware_maps/carla/unicamp_converted.xodr", 'w')
f.write(xodr_data)
f.close()
# Out:
# Options: sw 1 ba 0 cross 1
# pj_obj_create: Cannot find proj.db
# pj_obj_create: Cannot find proj.db
# pj_obj_create: Cannot find proj.db
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|cycleway.lane|highway.cycleway' (first occurrence for edge '77669837').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|cycleway.lane|highway.cycleway' (first occurrence for edge '77669837').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurrence for edge '179051712').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.residential' (first occurrence for edge '890559137').
# Warning: Could not find corresponding edge or compatible lane for free-floating pt stop '2749646013' (Meio Ambiente). Thus, it will be removed!
# Warning: Could not find corresponding edge or compatible lane for free-floating pt stop '2749646016' (Editora). Thus, it will be removed!
# Warning: Not joining junctions 5419179011,5419179015,860793263 (not compact (maxEdge=237036477#21 length=6.05)).
# Warning: Not joining junctions 5191743036,5419178996 (only 1 edge within and no cross-traffic).
# Warning: Not joining junctions 5191743041,6226438952 (only 1 edge within and no cross-traffic).
# Warning: Not joining junctions 5202963791,5202963793 (only 1 edge within and no cross-traffic).
# Warning: Not joining junctions 5202963796,5202963798 (only 1 edge within and no cross-traffic).
# pj_obj_create: Cannot find proj.db
# Warning: Found sharp turn with radius 8.94 at the start of edge '665220625'.
# Warning: Invalid pedestrian topology: crossing ':10123122434_c1' across [-1388130341#0 1388130341#0] has no target.
# Warning: Speed of straight connection '828912083_0->447326323#1_1' reduced by 14.92 due to turning radius of 9.68 (length=4.36, angle=43.23).
# Warning: Speed of straight connection '535556339#0_0->535556340_0' reduced by 14.17 due to turning radius of 11.79 (length=18.82, angle=113.46).
# Warning: Speed of straight connection '537250021_0->329703619#4_1' reduced by 14.83 due to turning radius of 9.93 (length=8.34, angle=67.60).
# Warning: Speed of straight connection '75701376#7_0->75701376#8_0' reduced by 7.77 due to turning radius of 37.97 (length=16.06, angle=39.77).
# Warning: Speed of straight connection '77674950#7_0->447326496#0_1' reduced by 13.70 due to turning radius of 23.22 (length=8.80, angle=37.53).
# Warning: Intersecting left turns at junction 'cluster_3901900946_3901900949' from lane '386834060#0_0' and lane '386834059#2_0' (increase junction radius to avoid this).
# Warning: Could not compute smooth shape for edge '89478572#9'.
# Warning: Could not compute smooth shape from lane '89478572#9_1' to lane '889999539_2'. Use option 'junctions.scurve-stretch' or increase radius of junction '1037621615' to fix this.
# Warning: Could not compute smooth shape from lane '89478572#3_0' to lane '75416306#0_0'. Use option 'junctions.scurve-stretch' or increase radius of junction '1037621679' to fix this.
# Warning: Could not compute smooth shape from lane '535556337#6_0' to lane '75701376#0_0'. Use option 'junctions.scurve-stretch' or increase radius of junction '8441772393' to fix this.
# Warning: Could not compute smooth shape from lane '179051712#1_0' to lane '890559137#0_1'. Use option 'junctions.scurve-stretch' or increase radius of junction '914123659' to fix this.
# Warning: Could not compute smooth shape from lane '535725903#0_0' to lane '769466394#8_0'. Use option 'junctions.scurve-stretch' or increase radius of junction 'cluster_5191765782_8247125431' to fix this.
# Warning: 9 total messages of type: Speed of % connection '%' reduced by % due to turning radius of % (length=%, angle=%).

# %%
# Define the desired settings. In this case, default values.
settings = carla.Osm2OdrSettings()
# enable traffic light generation from OSM data
settings.generate_traffic_lights = True
# Convert to .xodr
xodr_data = carla.Osm2Odr.convert(osm_data, settings)
# Out:
# Options: sw 1 ba 0 cross 1
# pj_obj_create: Cannot find proj.db
# pj_obj_create: Cannot find proj.db
# pj_obj_create: Cannot find proj.db
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|cycleway.lane|highway.cycleway' (first occurrence for edge '77669837').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|cycleway.lane|highway.cycleway' (first occurrence for edge '77669837').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurrence for edge '179051712').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.residential' (first occurrence for edge '890559137').
# Warning: Could not find corresponding edge or compatible lane for free-floating pt stop '2749646013' (Meio Ambiente). Thus, it will be removed!
# Warning: Could not find corresponding edge or compatible lane for free-floating pt stop '2749646016' (Editora). Thus, it will be removed!
# Warning: Not joining junctions 5419179011,5419179015,860793263 (not compact (maxEdge=237036477#21 length=6.05)).
# Warning: Not joining junctions 5191743036,5419178996 (only 1 edge within and no cross-traffic).
# Warning: Not joining junctions 5191743041,6226438952 (only 1 edge within and no cross-traffic).
# Warning: Not joining junctions 5202963791,5202963793 (only 1 edge within and no cross-traffic).
# Warning: Not joining junctions 5202963796,5202963798 (only 1 edge within and no cross-traffic).
# pj_obj_create: Cannot find proj.db
# Warning: Found sharp turn with radius 8.94 at the start of edge '665220625'.
# Warning: Invalid pedestrian topology: crossing ':10123122434_c1' across [-1388130341#0 1388130341#0] has no target.
# Warning: Speed of straight connection '828912083_0->447326323#1_1' reduced by 14.92 due to turning radius of 9.68 (length=4.36, angle=43.23).
# Warning: Speed of straight connection '535556339#0_0->535556340_0' reduced by 14.17 due to turning radius of 11.79 (length=18.82, angle=113.46).
# Warning: Speed of straight connection '537250021_0->329703619#4_1' reduced by 14.83 due to turning radius of 9.93 (length=8.34, angle=67.60).
# Warning: Speed of straight connection '75701376#7_0->75701376#8_0' reduced by 7.77 due to turning radius of 37.97 (length=16.06, angle=39.77).
# Warning: Speed of straight connection '77674950#7_0->447326496#0_1' reduced by 13.70 due to turning radius of 23.22 (length=8.80, angle=37.53).
# Warning: Intersecting left turns at junction 'cluster_3901900946_3901900949' from lane '386834060#0_0' and lane '386834059#2_0' (increase junction radius to avoid this).
# Warning: Could not compute smooth shape for edge '89478572#9'.
# Warning: Could not compute smooth shape from lane '89478572#9_1' to lane '889999539_2'. Use option 'junctions.scurve-stretch' or increase radius of junction '1037621615' to fix this.
# Warning: Could not compute smooth shape from lane '89478572#3_0' to lane '75416306#0_0'. Use option 'junctions.scurve-stretch' or increase radius of junction '1037621679' to fix this.
# Warning: Could not compute smooth shape from lane '535556337#6_0' to lane '75701376#0_0'. Use option 'junctions.scurve-stretch' or increase radius of junction '8441772393' to fix this.
# Warning: Could not compute smooth shape from lane '179051712#1_0' to lane '890559137#0_1'. Use option 'junctions.scurve-stretch' or increase radius of junction '914123659' to fix this.
# Warning: Could not compute smooth shape from lane '535725903#0_0' to lane '769466394#8_0'. Use option 'junctions.scurve-stretch' or increase radius of junction 'cluster_5191765782_8247125431' to fix this.
# Warning: 9 total messages of type: Speed of % connection '%' reduced by % due to turning radius of % (length=%, angle=%).
